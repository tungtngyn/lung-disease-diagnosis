# %% [markdown]
# # Multi-label Disease Classification of Chest X-Ray Images
#
# UC San Diego Machine Learning Engineering Bootcamp
#
# Tung Nguyen

# %% [markdown]
# ## Introduction

# %% [markdown]
# Dataset: NIH Chest X-Rays from Kaggle, https://www.kaggle.com/nih-chest-xrays/data
#
# This notebook contains a 2nd round of tuning, this time focusing on rescaling, samplewise normalization, and featurewise normalization, which the previous notebook (round 1) did not test.
#
# All models contain:
# - VGG16 as the base model
# - VGG16's preprocess_input applied in the ImageDataGenerator
# - preprocess_input: converts images from RGB to BGR, and zero-centers it with respects to ImageNet dataset, without scaling
# - Data augmentation (e.g. randomized flipping, rotation, etc.)
#
# The tests for rescaling, samplewise and featurewise standardization/normalization are done on the best performing model of Round 1 of tuning (weighted loss with no layers frozen).
#
# The descriptions of the models in this notebook are as follows:
#
# 6a\. Weighted loss + no blocks frozen, + rescaling by 1./255.
#
# 6b\. Weighted loss + no blocks frozen, + samplewise centering
#
# 6c\. Weighted loss + no blocks frozen, + samplewise centering + standardization
#
# 6d\. Weighted loss + no blocks frozen, + featurewise centering
#
# 6e\. Weighted loss + no blocks frozen, + featurewise centering + standardization
#
#
# Models f, g, h, i, j are the same as the 5 above, however, with no preprocess_input applied (these will serve as control tests)

# %% [markdown]
# ## Imports
# ---

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.utils.class_weight import compute_sample_weight, compute_class_weight
from skmultilearn.model_selection.iterative_stratification import iterative_train_test_split

from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, MaxPool2D, GlobalAveragePooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K

from sklearn.metrics import roc_curve, auc, precision_recall_curve, multilabel_confusion_matrix, classification_report

import warnings
warnings.filterwarnings('ignore')

# %%
random_state = 2022

train_size = 0.8
val_size = 0.2
test_size = 0.25

# %%
data_dir = '/Users/tungnguyen/Documents/capstone/data/'

# %% [markdown]
# ## Data Preprocessing
# ---

# %% [markdown]
# ### Wrangling

# %%
# Read CSV
df = pd.read_csv('/Users/tungnguyen/Documents/capstone/Data_Entry_2017.csv')

# Drop unnecessary columns
df.drop(['OriginalImage[Width', 'Height]', 'OriginalImagePixelSpacing[x', 'y]', 'Unnamed: 11'], axis=1, inplace=True)
print('Original DataFrame shape = {}'.format(df.shape))

# Some patients have age >200 - impute with mean of age from rows with the same Patient ID
err = df[df['Patient Age'] > 100]
df_dropped = df[df['Patient Age'] < 100]

for ind, row in err.iterrows():
    pid = row['Patient ID']
    avg = df_dropped[df_dropped['Patient ID'] == pid]['Patient Age'].mean()
    df.iat[ind, 4] = int(avg) if not(np.isnan(avg)) else -1

# There are ~3 patients with just a single datapoint - drop these 3 data points
df = df[df['Patient Age'] != -1]
df.reset_index(inplace=True)
print('Wrangled DataFrame shape = {}'.format(df.shape))

# Replace "No Finding" labels with blank
df['Finding Labels'] = df['Finding Labels'].replace(to_replace='No Finding', value='')

# Binarize
mlb = MultiLabelBinarizer()
lbl = mlb.fit_transform(df['Finding Labels'].str.split("|"))
df_mlb = pd.DataFrame(lbl, columns=mlb.classes_, dtype=np.float32)

# Drop 'No Finding' column
df_mlb.drop('', axis=1, inplace=True)

# Merge with main df
df = df.join(df_mlb)
print('Binarized DataFrame shape = {}'.format(df.shape))

# Get list of all labels
labels = [x for x in mlb.classes_ if x != '']
print()
print(labels)
# Out:
# Original DataFrame shape = (112120, 7)
# Wrangled DataFrame shape = (112117, 8)
# Binarized DataFrame shape = (112117, 22)
#
# ['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema', 'Effusion', 'Emphysema', 'Fibrosis', 'Hernia', 'Infiltration', 'Mass', 'Nodule', 'Pleural_Thickening', 'Pneumonia', 'Pneumothorax']

# %% [markdown]
# ### Splitting

# %%
tab_data_cols = ['Image Index', 'Finding Labels', 'Follow-up #', 'Patient ID', 'Patient Age', 'Patient Gender', 'View Position']
X = df[tab_data_cols]
y = df[labels]

X_train, y_train, X_test, y_test = iterative_train_test_split(
    X.to_numpy(), 
    y.to_numpy(), 
    test_size=test_size,
)

# %%
# Convert matrices to DataFrames for Keras' flow_from_dataframe
train_df = pd.DataFrame(
    np.hstack((X_train, y_train)),
    columns=[item for sublist in [tab_data_cols, labels] for item in sublist]
)

test_df = pd.DataFrame(
    np.hstack((X_test, y_test)),
    columns=[item for sublist in [tab_data_cols, labels] for item in sublist]
)

# Convert labels to float32 for Keras training
for col in train_df:
    if col in labels:
        train_df[col] = train_df[col].astype(np.float32)
        
for col in test_df:
    if col in labels:
        test_df[col] = test_df[col].astype(np.float32)

# %% [markdown]
# ### Sampling

# %%
plt.style.use('tableau-colorblind10')

# %%
def plot_df_freq(df, labels, offset=500, title='Frequency of Positive Labels'):
    df_pos = df[labels].sum()

    ax = df_pos.plot(kind='bar', figsize=(15, 7), rot=20);
    ax.set_title(title);
    ax.set_xlabel('Labels');
    ax.set_ylabel('Frequency');

    for i, val in enumerate(df_pos.values):
        ax.text(i, val + offset, int(val), ha = 'center')
        
    return df_pos

# %%
weights = []
for i, lbl in enumerate(labels):
    weights.append(dict(enumerate(compute_class_weight(class_weight='balanced', classes=[0., 1.], y=train_df[lbl]))))

# Normalized class weights for weighted loss
pos = np.array([])
neg = np.array([])
for d in weights:
    pos = np.append(pos, d[1] / sum(d.values()))
    neg = np.append(neg, d[0] / sum(d.values())) 
    
# Non-normalized class weights for weighted loss
pos_2 = np.array([])
neg_2 = np.array([])
for d in weights:
    pos_2 = np.append(pos_2, d[1])
    neg_2 = np.append(neg_2, d[0])

# %%
df_freq = plot_df_freq(train_df, labels, offset=250, title='Label Frequency in Training Data')

# %%
sample_weights = compute_sample_weight(class_weight=weights, y=train_df[labels])
train_df['sample_weights'] = sample_weights

sampled_train_df = train_df.sample(
    20000, 
    weights=sample_weights,
    random_state=random_state
)

plot_df_freq(sampled_train_df, labels, offset=100, title='Label Frequency in Sampled Training Data')
# Out:
# Atelectasis           5195.0
# Cardiomegaly          1713.0
# Consolidation         2787.0
# Edema                 1517.0
# Effusion              6368.0
# Emphysema             1600.0
# Fibrosis              1109.0
# Hernia                 170.0
# Infiltration          6911.0
# Mass                  3068.0
# Nodule                3051.0
# Pleural_Thickening    2047.0
# Pneumonia             1012.0
# Pneumothorax          2787.0
# dtype: float32

# %%
stratified_sampled_train_df = pd.DataFrame([])

n = 1500

# Sample each label
for lbl in labels:
    temp = train_df[train_df[lbl] == 1].sample(
        n,
        replace=True,
        random_state=random_state
    )
    
    stratified_sampled_train_df = pd.concat([stratified_sampled_train_df, temp])
    
# Sample null label
temp = train_df[train_df['Finding Labels'] == ''].sample(
    n,
    replace=False,
    random_state=random_state
)
stratified_sampled_train_df = pd.concat([stratified_sampled_train_df, temp])

plot_df_freq(stratified_sampled_train_df, labels, offset=100, title='Label Frequency in Stratified Sampled Training Data')
# Out:
# Atelectasis           4510.0
# Cardiomegaly          2105.0
# Consolidation         2802.0
# Edema                 2285.0
# Effusion              5509.0
# Emphysema             2147.0
# Fibrosis              1889.0
# Hernia                1536.0
# Infiltration          6450.0
# Mass                  3135.0
# Nodule                2920.0
# Pleural_Thickening    2558.0
# Pneumonia             2005.0
# Pneumothorax          2765.0
# dtype: float32

# %%
def get_weighted_loss(pos, neg, epsilon=1e-7):
    def weighted_loss(y_true, y_pred):
        loss = 0.0
        for i in range(len(pos)):
            loss += -1 * K.mean(pos * y_true * K.log(y_pred + epsilon) + 
                          (1 - y_true) * neg * K.log(1 - y_pred + epsilon))      
        return loss
    return weighted_loss

# %% [markdown]
# ### Helper Functions

# %%
def plot_losses(model_history, figsize=(15, 10)):
    fig, ax = plt.subplots(1, 1, figsize=figsize)
    ax.plot(model_history.history['val_loss'], 'r-o')
    ax.plot(model_history.history['loss'], 'b-o')
    ax.set_title('Training vs. Validation Loss')
    ax.legend(['Validation Loss', 'Training Loss'])
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')

def plot_roc_auc(y_pred, test_df, labels, model_name, figsize=(15, 10)):
    
    fig, ax = plt.subplots(1, 1, figsize=figsize)
    for i, lbl in enumerate(labels):
        fpr, tpr, thresholds = roc_curve(test_df[lbl].to_numpy(), y_pred[:, i])
        ax.plot(fpr, tpr, label = '%s (AUC: %0.2f)'  % (lbl, auc(fpr, tpr)))
        print("AUC = %0.4f for %s" % (auc(fpr, tpr), lbl))

    ax.legend()
    ax.set_title('ROC Curves for Test Data - ' + model_name);
    ax.set_xlabel('False Positive Rate (FPR)');
    ax.set_ylabel('True Positive Rate (TPR)');

def plot_precision_recall_auc(y_pred, test_df, labels, model_name, figsize=(15, 10)):
    
    fig, ax = plt.subplots(1, 1, figsize=figsize)
    for i, lbl in enumerate(labels):
        pr, rc, thresholds = precision_recall_curve(test_df[lbl].to_numpy(), y_pred[:, i])
        ax.plot(rc, pr, label = '%s (AUC: %0.4f)'  % (lbl, auc(rc, pr)))
        print("AUC = %0.4f for %s" % (auc(rc, pr), lbl))

    ax.legend()
    ax.set_title('Precision-Recall Curves for Test Data - ' + model_name);
    ax.set_xlabel('Recall');
    ax.set_ylabel('Precision');

# %%
def datagen_from_df(train_df, test_df, x_col, y_cols, data_path, preproc_func=None,
                    target_size=(256, 256), val_split=0.2, batch_size=64, sample_size=1000, color_mode='rgb', 
                    sample_center=False, sample_std=False, feature_center=False, feature_std=False, rescale_factor=None, 
                    weight_col=None, random_state=2022):

    datagen = ImageDataGenerator(
        preprocessing_function=preproc_func,
        validation_split=val_split,
        samplewise_center=sample_center,
        samplewise_std_normalization=sample_std,
        featurewise_center=feature_center,
        featurewise_std_normalization=feature_std,
        rescale=rescale_factor,
        horizontal_flip = True, 
        vertical_flip = False, 
        height_shift_range= 0.05, 
        width_shift_range=0.1, 
        rotation_range=5, 
        shear_range = 0.1,
        fill_mode = 'reflect',
        zoom_range=0.15,
    )

    if feature_center or feature_std:
        raw_train_generator = ImageDataGenerator().flow_from_dataframe(
            train_df,   
            data_path,
            shuffle=True,
            batch_size=sample_size,
            class_mode='raw',
            color_mode=color_mode,
            target_size=target_size,
            x_col=x_col,
            y_col=y_cols,
            seed=random_state
        )

        first_batch = raw_train_generator.next()
        data_sample = first_batch[0]
        datagen.fit(data_sample, augment=False, rounds=1, seed=random_state)

    train_generator = datagen.flow_from_dataframe(
        train_df,   
        data_path,
        shuffle=True,
        batch_size=batch_size,
        class_mode='raw',
        color_mode=color_mode,
        target_size=target_size,
        x_col=x_col,
        y_col=y_cols,
        weight_col=weight_col,
        subset='training',
        seed=random_state
    )

    validation_generator = datagen.flow_from_dataframe(
        train_df,
        data_path,
        shuffle=False,
        batch_size=batch_size,
        class_mode='raw',
        color_mode=color_mode,
        target_size=target_size,
        x_col=x_col,
        y_col=y_cols,
        subset='validation',
        seed=random_state
    )

    test_generator = datagen.flow_from_dataframe(
        test_df,
        data_path,
        shuffle=False,
        batch_size=batch_size,
        class_mode='raw',
        color_mode=color_mode,
        target_size=target_size,
        x_col=x_col,
        y_col=y_cols,
        seed=random_state
    )
    
    return train_generator, validation_generator, test_generator

# %%
# Base Models
base_model = VGG16(
    include_top=False,
    weights="imagenet",
    input_shape=(256, 256, 3)
)

# Callbacks
early = EarlyStopping(
    monitor="val_loss",
    mode="min", 
    patience=8
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.2,
    patience=4, 
    min_lr=0.001
)
# Out:
# Metal device set to: Apple M1 Max
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
# 2022-01-30 19:02:01.769487: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-01-30 19:02:01.769621: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## VGG16 Trade Studies
# ---

# %% [markdown]
# ### DataGenerators

# %%
train_generator_1, valid_generator_1, test_generator_1 = datagen_from_df(
    stratified_sampled_train_df, test_df, x_col='Image Index', y_cols=labels, data_path=data_dir, preproc_func=preprocess_input,
    target_size=(256, 256), val_split=val_size, batch_size=64, color_mode='rgb', 
    sample_center=False, sample_std=False, feature_center=False, feature_std=False,
    weight_col=None, rescale_factor=1./255.
)
# Out:
# Found 18000 validated image filenames.
# Found 4500 validated image filenames.
# Found 28030 validated image filenames.

# %%
train_generator_2, valid_generator_2, test_generator_2 = datagen_from_df(
    stratified_sampled_train_df, test_df, x_col='Image Index', y_cols=labels, data_path=data_dir, preproc_func=preprocess_input,
    target_size=(256, 256), val_split=val_size, batch_size=64, color_mode='rgb', 
    sample_center=True, sample_std=False, feature_center=False, feature_std=False,
    weight_col=None, rescale_factor=None
)
# Out:
# Found 18000 validated image filenames.
# Found 4500 validated image filenames.
# Found 28030 validated image filenames.

# %%
train_generator_3, valid_generator_3, test_generator_3 = datagen_from_df(
    stratified_sampled_train_df, test_df, x_col='Image Index', y_cols=labels, data_path=data_dir, preproc_func=preprocess_input,
    target_size=(256, 256), val_split=val_size, batch_size=64, color_mode='rgb', 
    sample_center=True, sample_std=True, feature_center=False, feature_std=False,
    weight_col=None, rescale_factor=None
)
# Out:
# Found 18000 validated image filenames.
# Found 4500 validated image filenames.
# Found 28030 validated image filenames.

# %%
train_generator_4, valid_generator_4, test_generator_4 = datagen_from_df(
    stratified_sampled_train_df, test_df, x_col='Image Index', y_cols=labels, data_path=data_dir, preproc_func=preprocess_input,
    target_size=(256, 256), val_split=val_size, batch_size=64, color_mode='rgb', 
    sample_center=False, sample_std=False, feature_center=True, feature_std=False,
    weight_col=None, rescale_factor=None
)
# Out:
# Found 22500 validated image filenames.
# Found 18000 validated image filenames.
# Found 4500 validated image filenames.
# Found 28030 validated image filenames.

# %%
train_generator_5, valid_generator_5, test_generator_5 = datagen_from_df(
    stratified_sampled_train_df, test_df, x_col='Image Index', y_cols=labels, data_path=data_dir, preproc_func=preprocess_input,
    target_size=(256, 256), val_split=val_size, batch_size=64, color_mode='rgb', 
    sample_center=False, sample_std=False, feature_center=True, feature_std=True,
    weight_col=None, rescale_factor=None
)
# Out:
# Found 22500 validated image filenames.
# Found 18000 validated image filenames.
# Found 4500 validated image filenames.
# Found 28030 validated image filenames.

# %%
train_generator_6, valid_generator_6, test_generator_6 = datagen_from_df(
    stratified_sampled_train_df, test_df, x_col='Image Index', y_cols=labels, data_path=data_dir, preproc_func=None,
    target_size=(256, 256), val_split=val_size, batch_size=64, color_mode='rgb', 
    sample_center=False, sample_std=False, feature_center=False, feature_std=False,
    weight_col=None, rescale_factor=1./255.
)
# Out:
# Found 18000 validated image filenames.
# Found 4500 validated image filenames.
# Found 28030 validated image filenames.

# %%
train_generator_7, valid_generator_7, test_generator_7 = datagen_from_df(
    stratified_sampled_train_df, test_df, x_col='Image Index', y_cols=labels, data_path=data_dir, preproc_func=None,
    target_size=(256, 256), val_split=val_size, batch_size=64, color_mode='rgb', 
    sample_center=True, sample_std=False, feature_center=False, feature_std=False,
    weight_col=None, rescale_factor=None
)
# Out:
# Found 18000 validated image filenames.
# Found 4500 validated image filenames.
# Found 28030 validated image filenames.

# %%
train_generator_8, valid_generator_8, test_generator_8 = datagen_from_df(
    stratified_sampled_train_df, test_df, x_col='Image Index', y_cols=labels, data_path=data_dir, preproc_func=None,
    target_size=(256, 256), val_split=val_size, batch_size=64, color_mode='rgb', 
    sample_center=True, sample_std=True, feature_center=False, feature_std=False,
    weight_col=None, rescale_factor=None
)
# Out:
# Found 18000 validated image filenames.
# Found 4500 validated image filenames.
# Found 28030 validated image filenames.

# %%
train_generator_9, valid_generator_9, test_generator_9 = datagen_from_df(
    stratified_sampled_train_df, test_df, x_col='Image Index', y_cols=labels, data_path=data_dir, preproc_func=None,
    target_size=(256, 256), val_split=val_size, batch_size=64, color_mode='rgb', 
    sample_center=False, sample_std=False, feature_center=True, feature_std=False,
    weight_col=None, rescale_factor=None
)
# Out:
# Found 22500 validated image filenames.
# Found 18000 validated image filenames.
# Found 4500 validated image filenames.
# Found 28030 validated image filenames.

# %%
train_generator_10, valid_generator_10, test_generator_10 = datagen_from_df(
    stratified_sampled_train_df, test_df, x_col='Image Index', y_cols=labels, data_path=data_dir, preproc_func=None,
    target_size=(256, 256), val_split=val_size, batch_size=64, color_mode='rgb', 
    sample_center=False, sample_std=False, feature_center=True, feature_std=True,
    weight_col=None, rescale_factor=None
)
# Out:
# Found 22500 validated image filenames.
# Found 18000 validated image filenames.
# Found 4500 validated image filenames.
# Found 28030 validated image filenames.

# %% [markdown]
# ### Model 6a

# %%
model = Sequential()

for layer in base_model.layers:
    model.add(layer)
    
for layer in model.layers:
    layer.trainable = True

model.add(Flatten())
model.add(Dense(len(labels), activation='sigmoid'))
    
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 14)                458766
#
# =================================================================
# Total params: 15,173,454
# Trainable params: 15,173,454
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=get_weighted_loss(pos, neg)
)

# %%
model_path = '/Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6a.h5'

chkpt_1 = ModelCheckpoint(
    model_path, 
    monitor='val_loss',
    verbose=1, 
    save_best_only=True, 
    mode='min', 
    save_weights_only = True
)

# %%
# %%time
history_1 = model.fit(
    train_generator_1, 
    validation_data=valid_generator_1,
    #steps_per_epoch=100, 
    #validation_steps=25, 
    epochs = 40,
    callbacks = [chkpt_1, early, reduce_lr]
)
# Out:
# 2022-01-30 19:02:50.058651: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/40
# 2022-01-30 19:02:50.562954: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 282/282 [==============================] - ETA: 0s - loss: 11.8305
# 2022-01-30 19:09:53.193670: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 00001: val_loss improved from inf to 22.98230, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6a.h5
# 282/282 [==============================] - 496s 2s/step - loss: 11.8305 - val_loss: 22.9823 - lr: 0.0010
# Epoch 2/40
# 282/282 [==============================] - ETA: 0s - loss: 11.8496
# Epoch 00002: val_loss did not improve from 22.98230
# 282/282 [==============================] - 489s 2s/step - loss: 11.8496 - val_loss: 22.9823 - lr: 0.0010
# Epoch 3/40
# 282/282 [==============================] - ETA: 0s - loss: 11.8496
# Epoch 00003: val_loss did not improve from 22.98230
# 282/282 [==============================] - 489s 2s/step - loss: 11.8496 - val_loss: 22.9823 - lr: 0.0010
# Epoch 4/40
# 282/282 [==============================] - ETA: 0s - loss: 11.8496
# Epoch 00004: val_loss did not improve from 22.98230
# 282/282 [==============================] - 489s 2s/step - loss: 11.8496 - val_loss: 22.9823 - lr: 0.0010
# Epoch 5/40
# 282/282 [==============================] - ETA: 0s - loss: 11.8496
# Epoch 00005: val_loss did not improve from 22.98230
# 282/282 [==============================] - 497s 2s/step - loss: 11.8496 - val_loss: 22.9823 - lr: 0.0010
# Epoch 6/40
# 282/282 [==============================] - ETA: 0s - loss: 11.8496
# Epoch 00006: val_loss did not improve from 22.98230
# 282/282 [==============================] - 493s 2s/step - loss: 11.8496 - val_loss: 22.9823 - lr: 0.0010
# Epoch 7/40
# 282/282 [==============================] - ETA: 0s - loss: 11.8496
# Epoch 00007: val_loss did not improve from 22.98230
# 282/282 [==============================] - 491s 2s/step - loss: 11.8496 - val_loss: 22.9823 - lr: 0.0010
# Epoch 8/40
# 282/282 [==============================] - ETA: 0s - loss: 11.8496
# Epoch 00008: val_loss did not improve from 22.98230
# 282/282 [==============================] - 491s 2s/step - loss: 11.8496 - val_loss: 22.9823 - lr: 0.0010
# Epoch 9/40
# 282/282 [==============================] - ETA: 0s - loss: 11.8496
# Epoch 00009: val_loss did not improve from 22.98230
# 282/282 [==============================] - 491s 2s/step - loss: 11.8496 - val_loss: 22.9823 - lr: 0.0010
# CPU times: user 54min 7s, sys: 13min 17s, total: 1h 7min 25s
# Wall time: 1h 13min 46s

# %%
y_pred_1 = model.predict(test_generator_1, batch_size=64, verbose=True)
# Out:
# 2022-01-30 20:16:36.380107: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 438/438 [==============================] - 463s 1s/step

# %%
plot_losses(history_1)

# %%
plot_roc_auc(y_pred_1, test_df, labels, model_name='VGG16 Model 6a')
# Out:
# AUC = 0.5000 for Atelectasis
# AUC = 0.5000 for Cardiomegaly
# AUC = 0.5000 for Consolidation
# AUC = 0.5000 for Edema
# AUC = 0.5000 for Effusion
# AUC = 0.5000 for Emphysema
# AUC = 0.5000 for Fibrosis
# AUC = 0.5000 for Hernia
# AUC = 0.5000 for Infiltration
# AUC = 0.5000 for Mass
# AUC = 0.5000 for Nodule
# AUC = 0.5000 for Pleural_Thickening
# AUC = 0.5000 for Pneumonia
# AUC = 0.5000 for Pneumothorax

# %% [markdown]
# ### Model 6b

# %%
model = Sequential()

for layer in base_model.layers:
    model.add(layer)
    
for layer in model.layers:
    layer.trainable = True

model.add(Flatten())
model.add(Dense(len(labels), activation='sigmoid'))
    
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten_1 (Flatten)         (None, 32768)             0
#
#  dense_1 (Dense)             (None, 14)                458766
#
# =================================================================
# Total params: 15,173,454
# Trainable params: 15,173,454
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=get_weighted_loss(pos, neg)
)

# %%
model_path = '/Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6b.h5'

chkpt_2 = ModelCheckpoint(
    model_path, 
    monitor='val_loss',
    verbose=1, 
    save_best_only=True, 
    mode='min', 
    save_weights_only = True
)

# %%
# %%time
history_2 = model.fit(
    train_generator_2, 
    validation_data=valid_generator_2,
    #steps_per_epoch=100, 
    #validation_steps=25, 
    epochs = 40,
    callbacks = [chkpt_2, early, reduce_lr]
)
# Out:
# Epoch 1/40
# 2022-01-30 20:24:21.390384: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 282/282 [==============================] - ETA: 0s - loss: 14.2388
# 2022-01-30 20:31:22.076787: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 00001: val_loss improved from inf to 23.21716, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6b.h5
# 282/282 [==============================] - 495s 2s/step - loss: 14.2388 - val_loss: 23.2172 - lr: 0.0010
# Epoch 2/40
# 282/282 [==============================] - ETA: 0s - loss: 14.2452
# Epoch 00002: val_loss did not improve from 23.21716
# 282/282 [==============================] - 488s 2s/step - loss: 14.2452 - val_loss: 23.2473 - lr: 0.0010
# Epoch 3/40
# 282/282 [==============================] - ETA: 0s - loss: 14.2109
# Epoch 00003: val_loss did not improve from 23.21716
# 282/282 [==============================] - 484s 2s/step - loss: 14.2109 - val_loss: 23.2250 - lr: 0.0010
# Epoch 4/40
# 282/282 [==============================] - ETA: 0s - loss: 13.8193
# Epoch 00004: val_loss improved from 23.21716 to 18.20602, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6b.h5
# 282/282 [==============================] - 483s 2s/step - loss: 13.8193 - val_loss: 18.2060 - lr: 0.0010
# Epoch 5/40
# 282/282 [==============================] - ETA: 0s - loss: 13.7150
# Epoch 00005: val_loss improved from 18.20602 to 18.16087, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6b.h5
# 282/282 [==============================] - 484s 2s/step - loss: 13.7150 - val_loss: 18.1609 - lr: 0.0010
# Epoch 6/40
# 282/282 [==============================] - ETA: 0s - loss: 13.6817
# Epoch 00006: val_loss did not improve from 18.16087
# 282/282 [==============================] - 483s 2s/step - loss: 13.6817 - val_loss: 18.1874 - lr: 0.0010
# Epoch 7/40
# 282/282 [==============================] - ETA: 0s - loss: 13.6870
# Epoch 00007: val_loss did not improve from 18.16087
# 282/282 [==============================] - 483s 2s/step - loss: 13.6870 - val_loss: 18.1715 - lr: 0.0010
# Epoch 8/40
# 282/282 [==============================] - ETA: 0s - loss: 13.6778
# Epoch 00008: val_loss improved from 18.16087 to 18.11840, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6b.h5
# 282/282 [==============================] - 483s 2s/step - loss: 13.6778 - val_loss: 18.1184 - lr: 0.0010
# Epoch 9/40
# 282/282 [==============================] - ETA: 0s - loss: 13.6997
# Epoch 00009: val_loss did not improve from 18.11840
# 282/282 [==============================] - 484s 2s/step - loss: 13.6997 - val_loss: 18.1868 - lr: 0.0010
# Epoch 10/40
# 282/282 [==============================] - ETA: 0s - loss: 13.7200
# Epoch 00010: val_loss did not improve from 18.11840
# 282/282 [==============================] - 483s 2s/step - loss: 13.7200 - val_loss: 18.2329 - lr: 0.0010
# Epoch 11/40
# 282/282 [==============================] - ETA: 0s - loss: 13.6746
# Epoch 00011: val_loss did not improve from 18.11840
# 282/282 [==============================] - 483s 2s/step - loss: 13.6746 - val_loss: 18.2434 - lr: 0.0010
# Epoch 12/40
# 282/282 [==============================] - ETA: 0s - loss: 13.7199
# Epoch 00012: val_loss did not improve from 18.11840
# 282/282 [==============================] - 482s 2s/step - loss: 13.7199 - val_loss: 18.2042 - lr: 0.0010
# Epoch 13/40
# 282/282 [==============================] - ETA: 0s - loss: 13.6703
# Epoch 00013: val_loss did not improve from 18.11840
# 282/282 [==============================] - 484s 2s/step - loss: 13.6703 - val_loss: 18.1326 - lr: 0.0010
# Epoch 14/40
# 282/282 [==============================] - ETA: 0s - loss: 13.6664
# Epoch 00014: val_loss did not improve from 18.11840
# 282/282 [==============================] - 482s 2s/step - loss: 13.6664 - val_loss: 18.1603 - lr: 0.0010
# Epoch 15/40
# 282/282 [==============================] - ETA: 0s - loss: 13.6729
# Epoch 00015: val_loss did not improve from 18.11840
# 282/282 [==============================] - 482s 2s/step - loss: 13.6729 - val_loss: 18.1845 - lr: 0.0010
# Epoch 16/40
# 282/282 [==============================] - ETA: 0s - loss: 13.7447
# Epoch 00016: val_loss did not improve from 18.11840
# 282/282 [==============================] - 482s 2s/step - loss: 13.7447 - val_loss: 18.2743 - lr: 0.0010
# CPU times: user 1h 35min 8s, sys: 20min 47s, total: 1h 55min 55s
# Wall time: 2h 9min 7s

# %%
y_pred_2 = model.predict(test_generator_2, batch_size=64, verbose=True)
# Out:
# 2022-01-30 22:33:45.161427: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 438/438 [==============================] - 452s 1s/step

# %%
plot_losses(history_2)

# %%
plot_roc_auc(y_pred_2, test_df, labels, model_name='VGG16 Model 6b')
# Out:
# AUC = 0.5000 for Atelectasis
# AUC = 0.5000 for Cardiomegaly
# AUC = 0.4434 for Consolidation
# AUC = 0.4933 for Edema
# AUC = 0.5005 for Effusion
# AUC = 0.5000 for Emphysema
# AUC = 0.5000 for Fibrosis
# AUC = 0.5000 for Hernia
# AUC = 0.5000 for Infiltration
# AUC = 0.5000 for Mass
# AUC = 0.5170 for Nodule
# AUC = 0.4817 for Pleural_Thickening
# AUC = 0.4963 for Pneumonia
# AUC = 0.5000 for Pneumothorax

# %% [markdown]
# ### Model 6c

# %%
model = Sequential()

for layer in base_model.layers:
    model.add(layer)
    
for layer in model.layers:
    layer.trainable = True

model.add(Flatten())
model.add(Dense(len(labels), activation='sigmoid'))
    
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten_2 (Flatten)         (None, 32768)             0
#
#  dense_2 (Dense)             (None, 14)                458766
#
# =================================================================
# Total params: 15,173,454
# Trainable params: 15,173,454
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=get_weighted_loss(pos, neg)
)

# %%
model_path = '/Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6c.h5'

chkpt_3 = ModelCheckpoint(
    model_path, 
    monitor='val_loss',
    verbose=1, 
    save_best_only=True, 
    mode='min', 
    save_weights_only = True
)

# %%
# %%time
history_3 = model.fit(
    train_generator_3, 
    validation_data=valid_generator_3,
    #steps_per_epoch=100, 
    #validation_steps=25, 
    epochs = 40,
    callbacks = [chkpt_3, early, reduce_lr]
)
# Out:
# Epoch 1/40
# 2022-01-30 22:41:19.120085: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 282/282 [==============================] - ETA: 0s - loss: 13.0554
# 2022-01-30 22:48:11.832274: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 00001: val_loss improved from inf to 17.20459, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6c.h5
# 282/282 [==============================] - 487s 2s/step - loss: 13.0554 - val_loss: 17.2046 - lr: 0.0010
# Epoch 2/40
# 282/282 [==============================] - ETA: 0s - loss: 13.0752
# Epoch 00002: val_loss did not improve from 17.20459
# 282/282 [==============================] - 484s 2s/step - loss: 13.0752 - val_loss: 17.2181 - lr: 0.0010
# Epoch 3/40
# 282/282 [==============================] - ETA: 0s - loss: 13.0781
# Epoch 00003: val_loss did not improve from 17.20459
# 282/282 [==============================] - 484s 2s/step - loss: 13.0781 - val_loss: 17.2906 - lr: 0.0010
# Epoch 4/40
# 282/282 [==============================] - ETA: 0s - loss: 13.0986
# Epoch 00004: val_loss improved from 17.20459 to 17.11476, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6c.h5
# 282/282 [==============================] - 484s 2s/step - loss: 13.0986 - val_loss: 17.1148 - lr: 0.0010
# Epoch 5/40
# 282/282 [==============================] - ETA: 0s - loss: 13.2751
# Epoch 00005: val_loss did not improve from 17.11476
# 282/282 [==============================] - 486s 2s/step - loss: 13.2751 - val_loss: 18.1387 - lr: 0.0010
# Epoch 6/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2231
# Epoch 00006: val_loss did not improve from 17.11476
# 282/282 [==============================] - 484s 2s/step - loss: 16.2231 - val_loss: 18.1777 - lr: 0.0010
# Epoch 7/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2164
# Epoch 00007: val_loss did not improve from 17.11476
# 282/282 [==============================] - 484s 2s/step - loss: 16.2164 - val_loss: 18.1086 - lr: 0.0010
# Epoch 8/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1954
# Epoch 00008: val_loss did not improve from 17.11476
# 282/282 [==============================] - 484s 2s/step - loss: 16.1954 - val_loss: 18.1469 - lr: 0.0010
# Epoch 9/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2148
# Epoch 00009: val_loss did not improve from 17.11476
# 282/282 [==============================] - 485s 2s/step - loss: 16.2148 - val_loss: 18.0932 - lr: 0.0010
# Epoch 10/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2234
# Epoch 00010: val_loss did not improve from 17.11476
# 282/282 [==============================] - 485s 2s/step - loss: 16.2234 - val_loss: 18.1336 - lr: 0.0010
# Epoch 11/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1954
# Epoch 00011: val_loss did not improve from 17.11476
# 282/282 [==============================] - 484s 2s/step - loss: 16.1954 - val_loss: 18.1182 - lr: 0.0010
# Epoch 12/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2080
# Epoch 00012: val_loss did not improve from 17.11476
# 282/282 [==============================] - 484s 2s/step - loss: 16.2080 - val_loss: 18.1305 - lr: 0.0010
# CPU times: user 1h 12min 54s, sys: 15min 2s, total: 1h 27min 57s
# Wall time: 1h 36min 58s

# %%
y_pred_3 = model.predict(test_generator_3, batch_size=64, verbose=True)
# Out:
# 2022-01-31 00:18:46.489470: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 438/438 [==============================] - 461s 1s/step

# %%
plot_losses(history_3)

# %%
plot_roc_auc(y_pred_3, test_df, labels, model_name='VGG16 Model 6c')
# Out:
# AUC = 0.5000 for Atelectasis
# AUC = 0.5005 for Cardiomegaly
# AUC = 0.4952 for Consolidation
# AUC = 0.5000 for Edema
# AUC = 0.5033 for Effusion
# AUC = 0.5000 for Emphysema
# AUC = 0.5000 for Fibrosis
# AUC = 0.5169 for Hernia
# AUC = 0.5000 for Infiltration
# AUC = 0.5000 for Mass
# AUC = 0.5007 for Nodule
# AUC = 0.5000 for Pleural_Thickening
# AUC = 0.5131 for Pneumonia
# AUC = 0.5000 for Pneumothorax

# %% [markdown]
# ### Model 6d

# %%
model = Sequential()

for layer in base_model.layers:
    model.add(layer)
    
for layer in model.layers:
    layer.trainable = True

model.add(Flatten())
model.add(Dense(len(labels), activation='sigmoid'))
    
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten_3 (Flatten)         (None, 32768)             0
#
#  dense_3 (Dense)             (None, 14)                458766
#
# =================================================================
# Total params: 15,173,454
# Trainable params: 15,173,454
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=get_weighted_loss(pos, neg)
)

# %%
model_path = '/Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6d.h5'

chkpt_4 = ModelCheckpoint(
    model_path, 
    monitor='val_loss',
    verbose=1, 
    save_best_only=True, 
    mode='min', 
    save_weights_only = True
)

# %%
# %%time
history_4 = model.fit(
    train_generator_4, 
    validation_data=valid_generator_4,
    #steps_per_epoch=100, 
    #validation_steps=25, 
    epochs = 40,
    callbacks = [chkpt_4, early, reduce_lr]
)
# Out:
# Epoch 1/40
# 2022-01-31 00:26:29.752310: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 282/282 [==============================] - ETA: 0s - loss: 16.2690
# 2022-01-31 00:33:21.707745: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 00001: val_loss improved from inf to 18.12039, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6d.h5
# 282/282 [==============================] - 484s 2s/step - loss: 16.2690 - val_loss: 18.1204 - lr: 0.0010
# Epoch 2/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2811
# Epoch 00002: val_loss did not improve from 18.12039
# 282/282 [==============================] - 482s 2s/step - loss: 16.2811 - val_loss: 18.1442 - lr: 0.0010
# Epoch 3/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2736
# Epoch 00003: val_loss did not improve from 18.12039
# 282/282 [==============================] - 482s 2s/step - loss: 16.2736 - val_loss: 18.1485 - lr: 0.0010
# Epoch 4/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2685
# Epoch 00004: val_loss did not improve from 18.12039
# 282/282 [==============================] - 482s 2s/step - loss: 16.2685 - val_loss: 18.1273 - lr: 0.0010
# Epoch 5/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2621
# Epoch 00005: val_loss did not improve from 18.12039
# 282/282 [==============================] - 483s 2s/step - loss: 16.2621 - val_loss: 18.1292 - lr: 0.0010
# Epoch 6/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2840
# Epoch 00006: val_loss did not improve from 18.12039
# 282/282 [==============================] - 482s 2s/step - loss: 16.2840 - val_loss: 18.1467 - lr: 0.0010
# Epoch 7/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2785
# Epoch 00007: val_loss did not improve from 18.12039
# 282/282 [==============================] - 482s 2s/step - loss: 16.2785 - val_loss: 18.1258 - lr: 0.0010
# Epoch 8/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2709
# Epoch 00008: val_loss did not improve from 18.12039
# 282/282 [==============================] - 482s 2s/step - loss: 16.2709 - val_loss: 18.1432 - lr: 0.0010
# Epoch 9/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2867
# Epoch 00009: val_loss did not improve from 18.12039
# 282/282 [==============================] - 483s 2s/step - loss: 16.2867 - val_loss: 18.1260 - lr: 0.0010
# CPU times: user 53min 10s, sys: 11min 12s, total: 1h 4min 22s
# Wall time: 1h 12min 23s

# %%
y_pred_4 = model.predict(test_generator_4, batch_size=64, verbose=True)
# Out:
# 2022-01-31 01:38:53.265855: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 438/438 [==============================] - 448s 1s/step

# %%
plot_losses(history_4)

# %%
plot_roc_auc(y_pred_4, test_df, labels, model_name='VGG16 Model 6d')
# Out:
# AUC = 0.5000 for Atelectasis
# AUC = 0.5004 for Cardiomegaly
# AUC = 0.4972 for Consolidation
# AUC = 0.5000 for Edema
# AUC = 0.5041 for Effusion
# AUC = 0.5000 for Emphysema
# AUC = 0.5000 for Fibrosis
# AUC = 0.4980 for Hernia
# AUC = 0.5000 for Infiltration
# AUC = 0.5000 for Mass
# AUC = 0.4997 for Nodule
# AUC = 0.5000 for Pleural_Thickening
# AUC = 0.5057 for Pneumonia
# AUC = 0.5000 for Pneumothorax

# %% [markdown]
# ### Model 6e

# %%
model = Sequential()

for layer in base_model.layers:
    model.add(layer)
    
for layer in model.layers:
    layer.trainable = True

model.add(Flatten())
model.add(Dense(len(labels), activation='sigmoid'))
    
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten_4 (Flatten)         (None, 32768)             0
#
#  dense_4 (Dense)             (None, 14)                458766
#
# =================================================================
# Total params: 15,173,454
# Trainable params: 15,173,454
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=get_weighted_loss(pos, neg)
)

# %%
model_path = '/Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6e.h5'

chkpt_5 = ModelCheckpoint(
    model_path, 
    monitor='val_loss',
    verbose=1, 
    save_best_only=True, 
    mode='min', 
    save_weights_only = True
)

# %%
# %%time
history_5 = model.fit(
    train_generator_5, 
    validation_data=valid_generator_5,
    #steps_per_epoch=100, 
    #validation_steps=25, 
    epochs = 40,
    callbacks = [chkpt_5, early, reduce_lr]
)
# Out:
# Epoch 1/40
# 2022-01-31 01:46:24.026227: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 282/282 [==============================] - ETA: 0s - loss: 16.2873
# 2022-01-31 01:53:16.263906: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 00001: val_loss improved from inf to 18.12794, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6e.h5
# 282/282 [==============================] - 485s 2s/step - loss: 16.2873 - val_loss: 18.1279 - lr: 0.0010
# Epoch 2/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2902
# Epoch 00002: val_loss improved from 18.12794 to 18.12024, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6e.h5
# 282/282 [==============================] - 482s 2s/step - loss: 16.2902 - val_loss: 18.1202 - lr: 0.0010
# Epoch 3/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2864
# Epoch 00003: val_loss did not improve from 18.12024
# 282/282 [==============================] - 482s 2s/step - loss: 16.2864 - val_loss: 18.1204 - lr: 0.0010
# Epoch 4/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2878
# Epoch 00004: val_loss did not improve from 18.12024
# 282/282 [==============================] - 482s 2s/step - loss: 16.2878 - val_loss: 18.1218 - lr: 0.0010
# Epoch 5/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2940
# Epoch 00005: val_loss improved from 18.12024 to 18.11814, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6e.h5
# 282/282 [==============================] - 484s 2s/step - loss: 16.2940 - val_loss: 18.1181 - lr: 0.0010
# Epoch 6/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2906
# Epoch 00006: val_loss did not improve from 18.11814
# 282/282 [==============================] - 482s 2s/step - loss: 16.2906 - val_loss: 18.1366 - lr: 0.0010
# Epoch 7/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2895
# Epoch 00007: val_loss improved from 18.11814 to 18.10435, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6e.h5
# 282/282 [==============================] - 482s 2s/step - loss: 16.2895 - val_loss: 18.1044 - lr: 0.0010
# Epoch 8/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2906
# Epoch 00008: val_loss did not improve from 18.10435
# 282/282 [==============================] - 482s 2s/step - loss: 16.2906 - val_loss: 18.1293 - lr: 0.0010
# Epoch 9/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3020
# Epoch 00009: val_loss improved from 18.10435 to 18.10275, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6e.h5
# 282/282 [==============================] - 483s 2s/step - loss: 16.3020 - val_loss: 18.1028 - lr: 0.0010
# Epoch 10/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2977
# Epoch 00010: val_loss did not improve from 18.10275
# 282/282 [==============================] - 482s 2s/step - loss: 16.2977 - val_loss: 18.1352 - lr: 0.0010
# Epoch 11/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2887
# Epoch 00011: val_loss did not improve from 18.10275
# 282/282 [==============================] - 483s 2s/step - loss: 16.2887 - val_loss: 18.1227 - lr: 0.0010
# Epoch 12/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2861
# Epoch 00012: val_loss did not improve from 18.10275
# 282/282 [==============================] - 482s 2s/step - loss: 16.2861 - val_loss: 18.1163 - lr: 0.0010
# Epoch 13/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2951
# Epoch 00013: val_loss did not improve from 18.10275
# 282/282 [==============================] - 483s 2s/step - loss: 16.2951 - val_loss: 18.1134 - lr: 0.0010
# Epoch 14/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3039
# Epoch 00014: val_loss improved from 18.10275 to 18.09922, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6e.h5
# 282/282 [==============================] - 483s 2s/step - loss: 16.3039 - val_loss: 18.0992 - lr: 0.0010
# Epoch 15/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2988
# Epoch 00015: val_loss did not improve from 18.09922
# 282/282 [==============================] - 483s 2s/step - loss: 16.2988 - val_loss: 18.1164 - lr: 0.0010
# Epoch 16/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2822
# Epoch 00016: val_loss did not improve from 18.09922
# 282/282 [==============================] - 483s 2s/step - loss: 16.2822 - val_loss: 18.1147 - lr: 0.0010
# Epoch 17/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2920
# Epoch 00017: val_loss did not improve from 18.09922
# 282/282 [==============================] - 482s 2s/step - loss: 16.2920 - val_loss: 18.1143 - lr: 0.0010
# Epoch 18/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2883
# Epoch 00018: val_loss did not improve from 18.09922
# 282/282 [==============================] - 482s 2s/step - loss: 16.2883 - val_loss: 18.1248 - lr: 0.0010
# Epoch 19/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2913
# Epoch 00019: val_loss did not improve from 18.09922
# 282/282 [==============================] - 482s 2s/step - loss: 16.2913 - val_loss: 18.1135 - lr: 0.0010
# Epoch 20/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2976
# Epoch 00020: val_loss did not improve from 18.09922
# 282/282 [==============================] - 482s 2s/step - loss: 16.2976 - val_loss: 18.1198 - lr: 0.0010
# Epoch 21/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2900
# Epoch 00021: val_loss did not improve from 18.09922
# 282/282 [==============================] - 483s 2s/step - loss: 16.2900 - val_loss: 18.1276 - lr: 0.0010
# Epoch 22/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2938
# Epoch 00022: val_loss did not improve from 18.09922
# 282/282 [==============================] - 483s 2s/step - loss: 16.2938 - val_loss: 18.1227 - lr: 0.0010
# CPU times: user 2h 10min 28s, sys: 27min 17s, total: 2h 37min 45s
# Wall time: 2h 56min 59s

# %%
y_pred_5 = model.predict(test_generator_5, batch_size=64, verbose=True)
# Out:
# 2022-01-31 04:43:45.013902: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 438/438 [==============================] - 450s 1s/step

# %%
plot_losses(history_5)

# %%
plot_roc_auc(y_pred_5, test_df, labels, model_name='VGG16 Model 6e')
# Out:
# AUC = 0.5000 for Atelectasis
# AUC = 0.5002 for Cardiomegaly
# AUC = 0.4985 for Consolidation
# AUC = 0.5000 for Edema
# AUC = 0.5025 for Effusion
# AUC = 0.5000 for Emphysema
# AUC = 0.5000 for Fibrosis
# AUC = 0.4911 for Hernia
# AUC = 0.5000 for Infiltration
# AUC = 0.5000 for Mass
# AUC = 0.4998 for Nodule
# AUC = 0.5000 for Pleural_Thickening
# AUC = 0.5054 for Pneumonia
# AUC = 0.5000 for Pneumothorax

# %% [markdown]
# ### Model 6f (no preprocess_input)

# %%
model = Sequential()

for layer in base_model.layers:
    model.add(layer)
    
for layer in model.layers:
    layer.trainable = True

model.add(Flatten())
model.add(Dense(len(labels), activation='sigmoid'))
    
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten_5 (Flatten)         (None, 32768)             0
#
#  dense_5 (Dense)             (None, 14)                458766
#
# =================================================================
# Total params: 15,173,454
# Trainable params: 15,173,454
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=get_weighted_loss(pos, neg)
)

# %%
model_path = '/Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6f.h5'

chkpt_6 = ModelCheckpoint(
    model_path, 
    monitor='val_loss',
    verbose=1, 
    save_best_only=True, 
    mode='min', 
    save_weights_only = True
)

# %%
# %%time
history_6 = model.fit(
    train_generator_6, 
    validation_data=valid_generator_6,
    #steps_per_epoch=100, 
    #validation_steps=25, 
    epochs = 40,
    callbacks = [chkpt_6, early, reduce_lr]
)
# Out:
# Epoch 1/40
# 2022-01-31 04:51:17.046364: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 282/282 [==============================] - ETA: 0s - loss: 16.3029
# 2022-01-31 04:58:08.476905: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 00001: val_loss improved from inf to 18.08756, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6f.h5
# 282/282 [==============================] - 483s 2s/step - loss: 16.3029 - val_loss: 18.0876 - lr: 0.0010
# Epoch 2/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3029
# Epoch 00002: val_loss did not improve from 18.08756
# 282/282 [==============================] - 482s 2s/step - loss: 16.3029 - val_loss: 18.0876 - lr: 0.0010
# Epoch 3/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3029
# Epoch 00003: val_loss did not improve from 18.08756
# 282/282 [==============================] - 482s 2s/step - loss: 16.3029 - val_loss: 18.0876 - lr: 0.0010
# Epoch 4/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3029
# Epoch 00004: val_loss did not improve from 18.08756
# 282/282 [==============================] - 481s 2s/step - loss: 16.3029 - val_loss: 18.0876 - lr: 0.0010
# Epoch 5/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3029
# Epoch 00005: val_loss did not improve from 18.08756
# 282/282 [==============================] - 482s 2s/step - loss: 16.3029 - val_loss: 18.0876 - lr: 0.0010
# Epoch 6/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3029
# Epoch 00006: val_loss did not improve from 18.08756
# 282/282 [==============================] - 483s 2s/step - loss: 16.3029 - val_loss: 18.0876 - lr: 0.0010
# Epoch 7/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3029
# Epoch 00007: val_loss did not improve from 18.08756
# 282/282 [==============================] - 482s 2s/step - loss: 16.3029 - val_loss: 18.0876 - lr: 0.0010
# Epoch 8/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3029
# Epoch 00008: val_loss did not improve from 18.08756
# 282/282 [==============================] - 482s 2s/step - loss: 16.3029 - val_loss: 18.0876 - lr: 0.0010
# Epoch 9/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3029
# Epoch 00009: val_loss did not improve from 18.08756
# 282/282 [==============================] - 482s 2s/step - loss: 16.3029 - val_loss: 18.0876 - lr: 0.0010
# CPU times: user 52min 51s, sys: 11min 6s, total: 1h 3min 57s
# Wall time: 1h 12min 18s

# %%
y_pred_6 = model.predict(test_generator_6, batch_size=64, verbose=True)
# Out:
# 2022-01-31 06:03:45.184018: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 438/438 [==============================] - 452s 1s/step

# %%
plot_losses(history_6)

# %%
plot_roc_auc(y_pred_6, test_df, labels, model_name='VGG16 Model 6f')
# Out:
# AUC = 0.5000 for Atelectasis
# AUC = 0.5000 for Cardiomegaly
# AUC = 0.5000 for Consolidation
# AUC = 0.5000 for Edema
# AUC = 0.5000 for Effusion
# AUC = 0.5000 for Emphysema
# AUC = 0.5000 for Fibrosis
# AUC = 0.5000 for Hernia
# AUC = 0.5000 for Infiltration
# AUC = 0.5000 for Mass
# AUC = 0.5000 for Nodule
# AUC = 0.5000 for Pleural_Thickening
# AUC = 0.5000 for Pneumonia
# AUC = 0.5000 for Pneumothorax

# %% [markdown]
# ### Model 6g (no preprocess_input)

# %%
model = Sequential()

for layer in base_model.layers:
    model.add(layer)
    
for layer in model.layers:
    layer.trainable = True

model.add(Flatten())
model.add(Dense(len(labels), activation='sigmoid'))
    
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten_6 (Flatten)         (None, 32768)             0
#
#  dense_6 (Dense)             (None, 14)                458766
#
# =================================================================
# Total params: 15,173,454
# Trainable params: 15,173,454
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=get_weighted_loss(pos, neg)
)

# %%
model_path = '/Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6g.h5'

chkpt_7 = ModelCheckpoint(
    model_path, 
    monitor='val_loss',
    verbose=1, 
    save_best_only=True, 
    mode='min', 
    save_weights_only = True
)

# %%
# %%time
history_7 = model.fit(
    train_generator_7, 
    validation_data=valid_generator_7,
    #steps_per_epoch=100, 
    #validation_steps=25, 
    epochs = 40,
    callbacks = [chkpt_7, early, reduce_lr]
)
# Out:
# Epoch 1/40
# 2022-01-31 06:11:19.630136: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 282/282 [==============================] - ETA: 0s - loss: 16.1917
# 2022-01-31 06:18:13.135068: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 00001: val_loss improved from inf to 18.15790, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6g.h5
# 282/282 [==============================] - 487s 2s/step - loss: 16.1917 - val_loss: 18.1579 - lr: 0.0010
# Epoch 2/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1685
# Epoch 00002: val_loss improved from 18.15790 to 18.13414, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6g.h5
# 282/282 [==============================] - 490s 2s/step - loss: 16.1685 - val_loss: 18.1341 - lr: 0.0010
# Epoch 3/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2060
# Epoch 00003: val_loss improved from 18.13414 to 18.13015, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6g.h5
# 282/282 [==============================] - 491s 2s/step - loss: 16.2060 - val_loss: 18.1301 - lr: 0.0010
# Epoch 4/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1972
# Epoch 00004: val_loss did not improve from 18.13015
# 282/282 [==============================] - 492s 2s/step - loss: 16.1972 - val_loss: 18.1458 - lr: 0.0010
# Epoch 5/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1981
# Epoch 00005: val_loss did not improve from 18.13015
# 282/282 [==============================] - 488s 2s/step - loss: 16.1981 - val_loss: 18.1691 - lr: 0.0010
# Epoch 6/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1825
# Epoch 00006: val_loss did not improve from 18.13015
# 282/282 [==============================] - 486s 2s/step - loss: 16.1825 - val_loss: 18.1715 - lr: 0.0010
# Epoch 7/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1578
# Epoch 00007: val_loss improved from 18.13015 to 18.10807, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6g.h5
# 282/282 [==============================] - 482s 2s/step - loss: 16.1578 - val_loss: 18.1081 - lr: 0.0010
# Epoch 8/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2134
# Epoch 00008: val_loss did not improve from 18.10807
# 282/282 [==============================] - 482s 2s/step - loss: 16.2134 - val_loss: 18.1440 - lr: 0.0010
# Epoch 9/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1901
# Epoch 00009: val_loss improved from 18.10807 to 18.10190, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6g.h5
# 282/282 [==============================] - 483s 2s/step - loss: 16.1901 - val_loss: 18.1019 - lr: 0.0010
# Epoch 10/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2071
# Epoch 00010: val_loss improved from 18.10190 to 18.10107, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6g.h5
# 282/282 [==============================] - 484s 2s/step - loss: 16.2071 - val_loss: 18.1011 - lr: 0.0010
# Epoch 11/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2037
# Epoch 00011: val_loss did not improve from 18.10107
# 282/282 [==============================] - 482s 2s/step - loss: 16.2037 - val_loss: 18.1185 - lr: 0.0010
# Epoch 12/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2007
# Epoch 00012: val_loss did not improve from 18.10107
# 282/282 [==============================] - 482s 2s/step - loss: 16.2007 - val_loss: 18.1301 - lr: 0.0010
# Epoch 13/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2019
# Epoch 00013: val_loss did not improve from 18.10107
# 282/282 [==============================] - 481s 2s/step - loss: 16.2019 - val_loss: 18.1192 - lr: 0.0010
# Epoch 14/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2003
# Epoch 00014: val_loss improved from 18.10107 to 18.09772, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6g.h5
# 282/282 [==============================] - 482s 2s/step - loss: 16.2003 - val_loss: 18.0977 - lr: 0.0010
# Epoch 15/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1765
# Epoch 00015: val_loss improved from 18.09772 to 18.08598, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6g.h5
# 282/282 [==============================] - 482s 2s/step - loss: 16.1765 - val_loss: 18.0860 - lr: 0.0010
# Epoch 16/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1875
# Epoch 00016: val_loss did not improve from 18.08598
# 282/282 [==============================] - 482s 2s/step - loss: 16.1875 - val_loss: 18.1037 - lr: 0.0010
# Epoch 17/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1773
# Epoch 00017: val_loss did not improve from 18.08598
# 282/282 [==============================] - 482s 2s/step - loss: 16.1773 - val_loss: 18.1323 - lr: 0.0010
# Epoch 18/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1599
# Epoch 00018: val_loss did not improve from 18.08598
# 282/282 [==============================] - 483s 2s/step - loss: 16.1599 - val_loss: 18.1914 - lr: 0.0010
# Epoch 19/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1785
# Epoch 00019: val_loss did not improve from 18.08598
# 282/282 [==============================] - 482s 2s/step - loss: 16.1785 - val_loss: 18.0996 - lr: 0.0010
# Epoch 20/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1796
# Epoch 00020: val_loss did not improve from 18.08598
# 282/282 [==============================] - 486s 2s/step - loss: 16.1796 - val_loss: 18.1675 - lr: 0.0010
# Epoch 21/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1710
# Epoch 00021: val_loss did not improve from 18.08598
# 282/282 [==============================] - 484s 2s/step - loss: 16.1710 - val_loss: 18.1779 - lr: 0.0010
# Epoch 22/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1840
# Epoch 00022: val_loss improved from 18.08598 to 18.08194, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6g.h5
# 282/282 [==============================] - 487s 2s/step - loss: 16.1840 - val_loss: 18.0819 - lr: 0.0010
# Epoch 23/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1691
# Epoch 00023: val_loss did not improve from 18.08194
# 282/282 [==============================] - 484s 2s/step - loss: 16.1691 - val_loss: 18.0877 - lr: 0.0010
# Epoch 24/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2029
# Epoch 00024: val_loss did not improve from 18.08194
# 282/282 [==============================] - 488s 2s/step - loss: 16.2029 - val_loss: 18.1689 - lr: 0.0010
# Epoch 25/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1870
# Epoch 00025: val_loss did not improve from 18.08194
# 282/282 [==============================] - 487s 2s/step - loss: 16.1870 - val_loss: 18.1373 - lr: 0.0010
# Epoch 26/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1911
# Epoch 00026: val_loss did not improve from 18.08194
# 282/282 [==============================] - 487s 2s/step - loss: 16.1911 - val_loss: 18.1291 - lr: 0.0010
# Epoch 27/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1980
# Epoch 00027: val_loss did not improve from 18.08194
# 282/282 [==============================] - 484s 2s/step - loss: 16.1980 - val_loss: 18.0979 - lr: 0.0010
# Epoch 28/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1612
# Epoch 00028: val_loss did not improve from 18.08194
# 282/282 [==============================] - 485s 2s/step - loss: 16.1612 - val_loss: 18.1812 - lr: 0.0010
# Epoch 29/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1716
# Epoch 00029: val_loss did not improve from 18.08194
# 282/282 [==============================] - 485s 2s/step - loss: 16.1716 - val_loss: 18.1951 - lr: 0.0010
# Epoch 30/40
# 282/282 [==============================] - ETA: 0s - loss: 16.1659
# Epoch 00030: val_loss did not improve from 18.08194
# 282/282 [==============================] - 486s 2s/step - loss: 16.1659 - val_loss: 18.1651 - lr: 0.0010
# CPU times: user 2h 58min 34s, sys: 40min 9s, total: 3h 38min 44s
# Wall time: 4h 2min 27s

# %%
y_pred_7 = model.predict(test_generator_7, batch_size=64, verbose=True)
# Out:
# 2022-01-31 10:13:46.735719: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 438/438 [==============================] - 467s 1s/step

# %%
plot_losses(history_7)

# %%
plot_roc_auc(y_pred_7, test_df, labels, model_name='VGG16 Model 6g')
# Out:
# AUC = 0.5000 for Atelectasis
# AUC = 0.4985 for Cardiomegaly
# AUC = 0.4951 for Consolidation
# AUC = 0.5000 for Edema
# AUC = 0.5048 for Effusion
# AUC = 0.5000 for Emphysema
# AUC = 0.5000 for Fibrosis
# AUC = 0.5240 for Hernia
# AUC = 0.5000 for Infiltration
# AUC = 0.5000 for Mass
# AUC = 0.5012 for Nodule
# AUC = 0.5000 for Pleural_Thickening
# AUC = 0.5164 for Pneumonia
# AUC = 0.5000 for Pneumothorax

# %% [markdown]
# ### Model 6h (no preprocess_input)

# %%
model = Sequential()

for layer in base_model.layers:
    model.add(layer)
    
for layer in model.layers:
    layer.trainable = True

model.add(Flatten())
model.add(Dense(len(labels), activation='sigmoid'))
    
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten_7 (Flatten)         (None, 32768)             0
#
#  dense_7 (Dense)             (None, 14)                458766
#
# =================================================================
# Total params: 15,173,454
# Trainable params: 15,173,454
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=get_weighted_loss(pos, neg)
)

# %%
model_path = '/Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6h.h5'

chkpt_8 = ModelCheckpoint(
    model_path, 
    monitor='val_loss',
    verbose=1, 
    save_best_only=True, 
    mode='min', 
    save_weights_only = True
)

# %%
# %%time
history_8 = model.fit(
    train_generator_8, 
    validation_data=valid_generator_8,
    #steps_per_epoch=100, 
    #validation_steps=25, 
    epochs = 40,
    callbacks = [chkpt_8, early, reduce_lr]
)
# Out:
# Epoch 1/40
# 2022-01-31 10:21:35.751765: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 282/282 [==============================] - ETA: 0s - loss: 16.2341
# 2022-01-31 10:28:36.913856: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 00001: val_loss improved from inf to 18.14407, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6h.h5
# 282/282 [==============================] - 497s 2s/step - loss: 16.2341 - val_loss: 18.1441 - lr: 0.0010
# Epoch 2/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2295
# Epoch 00002: val_loss did not improve from 18.14407
# 282/282 [==============================] - 490s 2s/step - loss: 16.2295 - val_loss: 18.1485 - lr: 0.0010
# Epoch 3/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2415
# Epoch 00003: val_loss did not improve from 18.14407
# 282/282 [==============================] - 489s 2s/step - loss: 16.2415 - val_loss: 18.1483 - lr: 0.0010
# Epoch 4/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2232
# Epoch 00004: val_loss improved from 18.14407 to 18.14175, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6h.h5
# 282/282 [==============================] - 487s 2s/step - loss: 16.2232 - val_loss: 18.1417 - lr: 0.0010
# Epoch 5/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2345
# Epoch 00005: val_loss did not improve from 18.14175
# 282/282 [==============================] - 488s 2s/step - loss: 16.2345 - val_loss: 18.1643 - lr: 0.0010
# Epoch 6/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2154
# Epoch 00006: val_loss did not improve from 18.14175
# 282/282 [==============================] - 486s 2s/step - loss: 16.2154 - val_loss: 18.1792 - lr: 0.0010
# Epoch 7/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2330
# Epoch 00007: val_loss improved from 18.14175 to 18.12454, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6h.h5
# 282/282 [==============================] - 484s 2s/step - loss: 16.2330 - val_loss: 18.1245 - lr: 0.0010
# Epoch 8/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2281
# Epoch 00008: val_loss did not improve from 18.12454
# 282/282 [==============================] - 492s 2s/step - loss: 16.2281 - val_loss: 18.1362 - lr: 0.0010
# Epoch 9/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2192
# Epoch 00009: val_loss improved from 18.12454 to 18.10038, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6h.h5
# 282/282 [==============================] - 493s 2s/step - loss: 16.2192 - val_loss: 18.1004 - lr: 0.0010
# Epoch 10/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2456
# Epoch 00010: val_loss did not improve from 18.10038
# 282/282 [==============================] - 489s 2s/step - loss: 16.2456 - val_loss: 18.1239 - lr: 0.0010
# Epoch 11/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2267
# Epoch 00011: val_loss did not improve from 18.10038
# 282/282 [==============================] - 495s 2s/step - loss: 16.2267 - val_loss: 18.1122 - lr: 0.0010
# Epoch 12/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2498
# Epoch 00012: val_loss did not improve from 18.10038
# 282/282 [==============================] - 491s 2s/step - loss: 16.2498 - val_loss: 18.1291 - lr: 0.0010
# Epoch 13/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2212
# Epoch 00013: val_loss did not improve from 18.10038
# 282/282 [==============================] - 493s 2s/step - loss: 16.2212 - val_loss: 18.1459 - lr: 0.0010
# Epoch 14/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2264
# Epoch 00014: val_loss did not improve from 18.10038
# 282/282 [==============================] - 490s 2s/step - loss: 16.2264 - val_loss: 18.1203 - lr: 0.0010
# Epoch 15/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2277
# Epoch 00015: val_loss did not improve from 18.10038
# 282/282 [==============================] - 488s 2s/step - loss: 16.2277 - val_loss: 18.1154 - lr: 0.0010
# Epoch 16/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2494
# Epoch 00016: val_loss did not improve from 18.10038
# 282/282 [==============================] - 486s 2s/step - loss: 16.2494 - val_loss: 18.1334 - lr: 0.0010
# Epoch 17/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2279
# Epoch 00017: val_loss did not improve from 18.10038
# 282/282 [==============================] - 487s 2s/step - loss: 16.2279 - val_loss: 18.1263 - lr: 0.0010
# CPU times: user 1h 44min 30s, sys: 25min 3s, total: 2h 9min 33s
# Wall time: 2h 18min 45s

# %%
y_pred_8 = model.predict(test_generator_8, batch_size=64, verbose=True)
# Out:
# 2022-01-31 12:40:20.549717: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 438/438 [==============================] - 471s 1s/step

# %%
plot_losses(history_8)

# %%
plot_roc_auc(y_pred_8, test_df, labels, model_name='VGG16 Model 6h')
# Out:
# AUC = 0.5000 for Atelectasis
# AUC = 0.5002 for Cardiomegaly
# AUC = 0.4953 for Consolidation
# AUC = 0.5000 for Edema
# AUC = 0.5033 for Effusion
# AUC = 0.5000 for Emphysema
# AUC = 0.5000 for Fibrosis
# AUC = 0.5121 for Hernia
# AUC = 0.5000 for Infiltration
# AUC = 0.5000 for Mass
# AUC = 0.5006 for Nodule
# AUC = 0.5000 for Pleural_Thickening
# AUC = 0.5138 for Pneumonia
# AUC = 0.5000 for Pneumothorax

# %% [markdown]
# ### Model 6i (no preprocess_input)

# %%
model = Sequential()

for layer in base_model.layers:
    model.add(layer)
    
for layer in model.layers:
    layer.trainable = True

model.add(Flatten())
model.add(Dense(len(labels), activation='sigmoid'))
    
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten_8 (Flatten)         (None, 32768)             0
#
#  dense_8 (Dense)             (None, 14)                458766
#
# =================================================================
# Total params: 15,173,454
# Trainable params: 15,173,454
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=get_weighted_loss(pos, neg)
)

# %%
model_path = '/Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6i.h5'

chkpt_9 = ModelCheckpoint(
    model_path, 
    monitor='val_loss',
    verbose=1, 
    save_best_only=True, 
    mode='min', 
    save_weights_only = True
)

# %%
# %%time
history_9 = model.fit(
    train_generator_9, 
    validation_data=valid_generator_9,
    #steps_per_epoch=100, 
    #validation_steps=25, 
    epochs = 40,
    callbacks = [chkpt_9, early, reduce_lr]
)
# Out:
# Epoch 1/40
# 2022-01-31 12:48:13.934485: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 282/282 [==============================] - ETA: 0s - loss: 16.2864
# 2022-01-31 12:55:08.235624: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 00001: val_loss improved from inf to 18.06174, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6i.h5
# 282/282 [==============================] - 486s 2s/step - loss: 16.2864 - val_loss: 18.0617 - lr: 0.0010
# Epoch 2/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3055
# Epoch 00002: val_loss improved from 18.06174 to 18.06141, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6i.h5
# 282/282 [==============================] - 482s 2s/step - loss: 16.3055 - val_loss: 18.0614 - lr: 0.0010
# Epoch 3/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2909
# Epoch 00003: val_loss did not improve from 18.06141
# 282/282 [==============================] - 483s 2s/step - loss: 16.2909 - val_loss: 18.0703 - lr: 0.0010
# Epoch 4/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2855
# Epoch 00004: val_loss did not improve from 18.06141
# 282/282 [==============================] - 483s 2s/step - loss: 16.2855 - val_loss: 18.0751 - lr: 0.0010
# Epoch 5/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2871
# Epoch 00005: val_loss did not improve from 18.06141
# 282/282 [==============================] - 484s 2s/step - loss: 16.2871 - val_loss: 18.1000 - lr: 0.0010
# Epoch 6/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2850
# Epoch 00006: val_loss did not improve from 18.06141
# 282/282 [==============================] - 482s 2s/step - loss: 16.2850 - val_loss: 18.0700 - lr: 0.0010
# Epoch 7/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2970
# Epoch 00007: val_loss did not improve from 18.06141
# 282/282 [==============================] - 483s 2s/step - loss: 16.2970 - val_loss: 18.0827 - lr: 0.0010
# Epoch 8/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3026
# Epoch 00008: val_loss did not improve from 18.06141
# 282/282 [==============================] - 482s 2s/step - loss: 16.3026 - val_loss: 18.0819 - lr: 0.0010
# Epoch 9/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2988
# Epoch 00009: val_loss improved from 18.06141 to 18.06063, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6i.h5
# 282/282 [==============================] - 487s 2s/step - loss: 16.2988 - val_loss: 18.0606 - lr: 0.0010
# Epoch 10/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3073
# Epoch 00010: val_loss improved from 18.06063 to 18.04286, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6i.h5
# 282/282 [==============================] - 488s 2s/step - loss: 16.3073 - val_loss: 18.0429 - lr: 0.0010
# Epoch 11/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3038
# Epoch 00011: val_loss did not improve from 18.04286
# 282/282 [==============================] - 488s 2s/step - loss: 16.3038 - val_loss: 18.0777 - lr: 0.0010
# Epoch 12/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3052
# Epoch 00012: val_loss did not improve from 18.04286
# 282/282 [==============================] - 483s 2s/step - loss: 16.3052 - val_loss: 18.0505 - lr: 0.0010
# Epoch 13/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2948
# Epoch 00013: val_loss did not improve from 18.04286
# 282/282 [==============================] - 485s 2s/step - loss: 16.2948 - val_loss: 18.0553 - lr: 0.0010
# Epoch 14/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2974
# Epoch 00014: val_loss did not improve from 18.04286
# 282/282 [==============================] - 484s 2s/step - loss: 16.2974 - val_loss: 18.0749 - lr: 0.0010
# Epoch 15/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3019
# Epoch 00015: val_loss did not improve from 18.04286
# 282/282 [==============================] - 484s 2s/step - loss: 16.3019 - val_loss: 18.0698 - lr: 0.0010
# Epoch 16/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3136
# Epoch 00016: val_loss did not improve from 18.04286
# 282/282 [==============================] - 484s 2s/step - loss: 16.3136 - val_loss: 18.1103 - lr: 0.0010
# Epoch 17/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3028
# Epoch 00017: val_loss did not improve from 18.04286
# 282/282 [==============================] - 488s 2s/step - loss: 16.3028 - val_loss: 18.0709 - lr: 0.0010
# Epoch 18/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2900
# Epoch 00018: val_loss did not improve from 18.04286
# 282/282 [==============================] - 485s 2s/step - loss: 16.2900 - val_loss: 18.0687 - lr: 0.0010
# CPU times: user 1h 46min 28s, sys: 24min 18s, total: 2h 10min 46s
# Wall time: 2h 25min 21s

# %%
y_pred_9 = model.predict(test_generator_9, batch_size=64, verbose=True)
# Out:
# 2022-01-31 15:13:35.189241: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 438/438 [==============================] - 461s 1s/step

# %%
plot_losses(history_9)

# %%
plot_roc_auc(y_pred_9, test_df, labels, model_name='VGG16 Model 6i')
# Out:
# AUC = 0.5000 for Atelectasis
# AUC = 0.4988 for Cardiomegaly
# AUC = 0.5002 for Consolidation
# AUC = 0.5000 for Edema
# AUC = 0.4976 for Effusion
# AUC = 0.5000 for Emphysema
# AUC = 0.5000 for Fibrosis
# AUC = 0.5103 for Hernia
# AUC = 0.5000 for Infiltration
# AUC = 0.5000 for Mass
# AUC = 0.5005 for Nodule
# AUC = 0.5000 for Pleural_Thickening
# AUC = 0.5030 for Pneumonia
# AUC = 0.5000 for Pneumothorax

# %% [markdown]
# ### Model 6j (no preprocess_input)

# %%
model = Sequential()

for layer in base_model.layers:
    model.add(layer)
    
for layer in model.layers:
    layer.trainable = True

model.add(Flatten())
model.add(Dense(len(labels), activation='sigmoid'))
    
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten_9 (Flatten)         (None, 32768)             0
#
#  dense_9 (Dense)             (None, 14)                458766
#
# =================================================================
# Total params: 15,173,454
# Trainable params: 15,173,454
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=get_weighted_loss(pos, neg)
)

# %%
model_path = '/Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6j.h5'

chkpt_10 = ModelCheckpoint(
    model_path, 
    monitor='val_loss',
    verbose=1, 
    save_best_only=True, 
    mode='min', 
    save_weights_only = True
)

# %%
# %%time
history_10 = model.fit(
    train_generator_10, 
    validation_data=valid_generator_10,
    #steps_per_epoch=100, 
    #validation_steps=25, 
    epochs = 40,
    callbacks = [chkpt_10, early, reduce_lr]
)
# Out:
# Epoch 1/40
# 2022-01-31 15:21:18.420400: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 282/282 [==============================] - ETA: 0s - loss: 16.2912
# 2022-01-31 15:28:13.988629: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 00001: val_loss improved from inf to 18.08879, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6j.h5
# 282/282 [==============================] - 489s 2s/step - loss: 16.2912 - val_loss: 18.0888 - lr: 0.0010
# Epoch 2/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3058
# Epoch 00002: val_loss improved from 18.08879 to 18.08504, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6j.h5
# 282/282 [==============================] - 485s 2s/step - loss: 16.3058 - val_loss: 18.0850 - lr: 0.0010
# Epoch 3/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2751
# Epoch 00003: val_loss improved from 18.08504 to 18.06687, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6j.h5
# 282/282 [==============================] - 482s 2s/step - loss: 16.2751 - val_loss: 18.0669 - lr: 0.0010
# Epoch 4/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2908
# Epoch 00004: val_loss did not improve from 18.06687
# 282/282 [==============================] - 483s 2s/step - loss: 16.2908 - val_loss: 18.0730 - lr: 0.0010
# Epoch 5/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2802
# Epoch 00005: val_loss did not improve from 18.06687
# 282/282 [==============================] - 485s 2s/step - loss: 16.2802 - val_loss: 18.1151 - lr: 0.0010
# Epoch 6/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3031
# Epoch 00006: val_loss did not improve from 18.06687
# 282/282 [==============================] - 485s 2s/step - loss: 16.3031 - val_loss: 18.0786 - lr: 0.0010
# Epoch 7/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2918
# Epoch 00007: val_loss did not improve from 18.06687
# 282/282 [==============================] - 485s 2s/step - loss: 16.2918 - val_loss: 18.0796 - lr: 0.0010
# Epoch 8/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2892
# Epoch 00008: val_loss did not improve from 18.06687
# 282/282 [==============================] - 485s 2s/step - loss: 16.2892 - val_loss: 18.0682 - lr: 0.0010
# Epoch 9/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2757
# Epoch 00009: val_loss improved from 18.06687 to 18.06678, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6j.h5
# 282/282 [==============================] - 488s 2s/step - loss: 16.2757 - val_loss: 18.0668 - lr: 0.0010
# Epoch 10/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2924
# Epoch 00010: val_loss improved from 18.06678 to 18.04730, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6j.h5
# 282/282 [==============================] - 485s 2s/step - loss: 16.2924 - val_loss: 18.0473 - lr: 0.0010
# Epoch 11/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2849
# Epoch 00011: val_loss did not improve from 18.04730
# 282/282 [==============================] - 486s 2s/step - loss: 16.2849 - val_loss: 18.1033 - lr: 0.0010
# Epoch 12/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2801
# Epoch 00012: val_loss did not improve from 18.04730
# 282/282 [==============================] - 485s 2s/step - loss: 16.2801 - val_loss: 18.0551 - lr: 0.0010
# Epoch 13/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2976
# Epoch 00013: val_loss improved from 18.04730 to 18.03977, saving model to /Users/tungnguyen/Documents/repos/mec-capstone/Round2/vgg16-model-6j.h5
# 282/282 [==============================] - 487s 2s/step - loss: 16.2976 - val_loss: 18.0398 - lr: 0.0010
# Epoch 14/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3060
# Epoch 00014: val_loss did not improve from 18.03977
# 282/282 [==============================] - 485s 2s/step - loss: 16.3060 - val_loss: 18.0839 - lr: 0.0010
# Epoch 15/40
# 282/282 [==============================] - ETA: 0s - loss: 16.3105
# Epoch 00015: val_loss did not improve from 18.03977
# 282/282 [==============================] - 486s 2s/step - loss: 16.3105 - val_loss: 18.0586 - lr: 0.0010
# Epoch 16/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2886
# Epoch 00016: val_loss did not improve from 18.03977
# 282/282 [==============================] - 486s 2s/step - loss: 16.2886 - val_loss: 18.0979 - lr: 0.0010
# Epoch 17/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2901
# Epoch 00017: val_loss did not improve from 18.03977
# 282/282 [==============================] - 488s 2s/step - loss: 16.2901 - val_loss: 18.0934 - lr: 0.0010
# Epoch 18/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2850
# Epoch 00018: val_loss did not improve from 18.03977
# 282/282 [==============================] - 483s 2s/step - loss: 16.2850 - val_loss: 18.0805 - lr: 0.0010
# Epoch 19/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2822
# Epoch 00019: val_loss did not improve from 18.03977
# 282/282 [==============================] - 490s 2s/step - loss: 16.2822 - val_loss: 18.0682 - lr: 0.0010
# Epoch 20/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2962
# Epoch 00020: val_loss did not improve from 18.03977
# 282/282 [==============================] - 486s 2s/step - loss: 16.2962 - val_loss: 18.1062 - lr: 0.0010
# Epoch 21/40
# 282/282 [==============================] - ETA: 0s - loss: 16.2839
# Epoch 00021: val_loss did not improve from 18.03977
# 282/282 [==============================] - 484s 2s/step - loss: 16.2839 - val_loss: 18.0641 - lr: 0.0010
# CPU times: user 2h 5min 11s, sys: 29min 33s, total: 2h 34min 45s
# Wall time: 2h 50min

# %%
y_pred_10 = model.predict(test_generator_10, batch_size=64, verbose=True)
# Out:
# 2022-01-31 18:11:18.010382: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 438/438 [==============================] - 460s 1s/step

# %%
plot_losses(history_10)

# %%
plot_roc_auc(y_pred_10, test_df, labels, model_name='VGG16 Model 6j')
# Out:
# AUC = 0.5000 for Atelectasis
# AUC = 0.4990 for Cardiomegaly
# AUC = 0.4996 for Consolidation
# AUC = 0.5000 for Edema
# AUC = 0.4986 for Effusion
# AUC = 0.5000 for Emphysema
# AUC = 0.5000 for Fibrosis
# AUC = 0.5023 for Hernia
# AUC = 0.5000 for Infiltration
# AUC = 0.5000 for Mass
# AUC = 0.5003 for Nodule
# AUC = 0.5000 for Pleural_Thickening
# AUC = 0.5031 for Pneumonia
# AUC = 0.5000 for Pneumothorax
